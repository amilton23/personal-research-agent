# %% [markdown]
# # Research Agent - Initial Research

# %%
from src.graph.research_graph import research_graph

result = research_graph.invoke({
    "query": "AI in cardiology diagnosis",
    "sources": [],
    "summary": "",
    "final_report": "",
    "messages": [],
})

print("--- SOURCES ---")
print(result["sources"])

print("--- FINAL REPORT ---")
print(result["final_report"])

print("--- EVALUATION ---")
print(result["summary"])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.graph.research_graph import research_graph
#       2
#       3 result = research_graph.invoke({
#       4     "query": "AI in cardiology diagnosis",
#
# File ~/projects/personal-research-agent/src/graph/research_graph.py:7
#       4 from typing import Annotated, TypedDict
#       5 import operator
# ----> 7 from src.agents.academic_researcher import academic_researcher_node
#       8 from src.agents.corporate_researcher import corporate_researcher_node
#       9 from src.llm_providers.openai import get_openai_llm
#
# File ~/projects/personal-research-agent/src/agents/academic_researcher.py:4
#       1 from src.llm_providers.gemini import get_gemini_llm
#       2 from langchain_core.messages import SystemMessage
# ----> 4 _llm = get_gemini_llm()
#       6 instructions = (
# ...
